# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # REMOVING UNNECCARY FEATURES AND ONE-HOT-ENCODING

# %%
df = pd.read_csv('CarPrice_Assignment.csv')

df = df.drop(['car_ID', 'CarName' , 'fuelsystem'  , 'symboling' ] , axis = 1)
#dropping peakrpm , fuelsystem due to redundancy and engine location because majority of them are located in the front 
df  = pd.get_dummies(df , columns=['fueltype', 'aspiration', 'doornumber', 'carbody', 
                                 'drivewheel', 'enginetype', 
                                 'cylindernumber' , 'enginelocation'], drop_first=True)


df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  ...  enginetype_ohcf  \
# 0         3.47    2.68               9.0         111  ...            False
# 1         3.47    2.68               9.0         111  ...            False
# 2         2.68    3.47               9.0         154  ...            False
# 3         3.19    3.40              10.0         102  ...            False
# 4         3.19    3.40               8.0         115  ...            False
# ..         ...     ...               ...         ...  ...              ...
# 200       3.78    3.15               9.5         114  ...            False
# 201       3.78    3.15               8.7         160  ...            False
# 202       3.58    2.87               8.8         134  ...            False
# 203       3.01    3.40              23.0         106  ...            False
# 204       3.78    3.15               9.5         114  ...            False
#
#      enginetype_ohcv  enginetype_rotor  cylindernumber_five  \
# 0              False             False                False
# 1              False             False                False
# 2               True             False                False
# 3              False             False                False
# 4              False             False                 True
# ..               ...               ...                  ...
# 200            False             False                False
# 201            False             False                False
# 202             True             False                False
# 203            False             False                False
# 204            False             False                False
#
#      cylindernumber_four  cylindernumber_six  cylindernumber_three  \
# 0                   True               False                 False
# 1                   True               False                 False
# 2                  False                True                 False
# 3                   True               False                 False
# 4                  False               False                 False
# ..                   ...                 ...                   ...
# 200                 True               False                 False
# 201                 True               False                 False
# 202                False                True                 False
# 203                False                True                 False
# 204                 True               False                 False
#
#      cylindernumber_twelve  cylindernumber_two  enginelocation_rear
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ..                     ...                 ...                  ...
# 200                  False               False                False
# 201                  False               False                False
# 202                  False               False                False
# 203                  False               False                False
# 204                  False               False                False
#
# [205 rows x 36 columns]

# %%
sns.histplot(df['carheight'] , kde = True)
print("carheight mean" , df['carheight'].mean())
sns.histplot(df['carwidth'] , kde = True)
# Out:
# carheight mean 53.72487804878049
# <Axes: xlabel='carheight', ylabel='Count'>

# %% [markdown]
# ## this is a non normal distribution about the mean , roughly all the coloumns potray the same

# %%
non_hot_encoded = df.select_dtypes(include=['float64', 'int64']).columns
# the hot encoded values are of uint8 that's why it gets excluded here

for i in non_hot_encoded:
    df[i] = (df[i] - df[i].mean())/df[i].std()

df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0    -1.686643  -0.425480 -0.842719  -2.015483   -0.014531    0.074267
# 1    -1.686643  -0.425480 -0.842719  -2.015483   -0.014531    0.074267
# 2    -0.706865  -0.230948 -0.190101  -0.542200    0.513625    0.602571
# 3     0.173274   0.206750  0.136209   0.235366   -0.419770   -0.430023
# 4     0.106848   0.206750  0.229440   0.235366    0.515545    0.218350
# ..         ...        ...       ...        ...         ...         ...
# 200   1.717669   1.195622  1.394830   0.726460    0.761377    0.338419
# 201   1.717669   1.195622  1.348215   0.726460    0.947672    0.338419
# 202   1.717669   1.195622  1.394830   0.726460    0.876611    1.106861
# 203   1.717669   1.195622  1.394830   0.726460    1.270327    0.434474
# 204   1.717669   1.195622  1.394830   0.726460    0.972640    0.338419
#
#      boreratio    stroke  compressionratio  horsepower  ...  enginetype_ohcf  \
# 0     0.517804 -1.834886         -0.287645    0.174057  ...            False
# 1     0.517804 -1.834886         -0.287645    0.174057  ...            False
# 2    -2.399008  0.684271         -0.287645    1.261448  ...            False
# 3    -0.516003  0.461055         -0.035885   -0.053537  ...            False
# 4    -0.516003  0.461055         -0.539405    0.275209  ...            False
# ..         ...       ...               ...         ...  ...              ...
# 200   1.662375 -0.336147         -0.161765    0.249921  ...            False
# 201   1.662375 -0.336147         -0.363173    1.413178  ...            False
# 202   0.923942 -1.229012         -0.337997    0.755685  ...            False
# 203  -1.180593  0.461055          3.236992    0.047616  ...            False
# 204   1.662375 -0.336147         -0.161765    0.249921  ...            False
#
#      enginetype_ohcv  enginetype_rotor  cylindernumber_five  \
# 0              False             False                False
# 1              False             False                False
# 2               True             False                False
# 3              False             False                False
# 4              False             False                 True
# ..               ...               ...                  ...
# 200            False             False                False
# 201            False             False                False
# 202             True             False                False
# 203            False             False                False
# 204            False             False                False
#
#      cylindernumber_four  cylindernumber_six  cylindernumber_three  \
# 0                   True               False                 False
# 1                   True               False                 False
# 2                  False                True                 False
# 3                   True               False                 False
# 4                  False               False                 False
# ..                   ...                 ...                   ...
# 200                 True               False                 False
# 201                 True               False                 False
# 202                False                True                 False
# 203                False                True                 False
# 204                 True               False                 False
#
#      cylindernumber_twelve  cylindernumber_two  enginelocation_rear
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ..                     ...                 ...                  ...
# 200                  False               False                False
# 201                  False               False                False
# 202                  False               False                False
# 203                  False               False                False
# 204                  False               False                False
#
# [205 rows x 36 columns]

# %% [markdown]
# # Removing outliers using Z-Score
# ## anything falling outside the range -3 and 3  be considered as an outlier

# %%
for i in non_hot_encoded:

    outliers  = df.loc[(df[i] > 3 ) | (df[i] < -3)]

    if not outliers.empty:
        print(f'outliers in the feature \n {i}')
        print()
        print(outliers.loc[: , i])
    else:
        print(f'outliers are not present : {i}')
# Out:
# outliers in the coloumn
#  wheelbase
#
# 73    3.677223
# Name: wheelbase, dtype: float64
# outliers not there in the coloumn : carlength
# outliers not there in the coloumn : carwidth
# outliers not there in the coloumn : carheight
# outliers not there in the coloumn : curbweight
# outliers in the coloumn
#  enginesize
#
# 47    3.148036
# 48    3.148036
# 49    4.780975
# 73    4.348726
# 74    4.252671
# Name: enginesize, dtype: float64
# outliers not there in the coloumn : boreratio
# outliers in the coloumn
#  stroke
#
# 111   -3.397400
# 113   -3.397400
# 134   -3.780057
# Name: stroke, dtype: float64
# outliers in the coloumn
#  compressionratio
#
# 63     3.161464
# 158    3.111112
# 159    3.111112
# 174    3.111112
# 182    3.236992
# 184    3.236992
# 187    3.236992
# 192    3.236992
# 203    3.236992
# Name: compressionratio, dtype: float64
# outliers in the coloumn
#  horsepower
#
# 49     3.992572
# 129    4.650065
# Name: horsepower, dtype: float64
# outliers in the coloumn
#  peakrpm
#
# 165    3.092081
# 166    3.092081
# Name: peakrpm, dtype: float64
# outliers in the coloumn
#  citympg
#
# 18    3.329260
# 30    3.634970
# 90    3.023549
# Name: citympg, dtype: float64
# outliers in the coloumn
#  highwaympg
#
# 18    3.230809
# 30    3.376022
# Name: highwaympg, dtype: float64
# outliers in the coloumn
#  price
#
# 16    3.509677
# 73    3.465240
# 74    4.021014
# Name: price, dtype: float64

# %% [markdown]
# ## deleting these outliers from the set

# %%
for i in non_hot_encoded:
    df = df.query(f"({i} <= 3) & ({i} >= -3)")
df.reset_index(drop=True, inplace=True)

# %%
for i , column in enumerate(non_hot_encoded , 1):
    plt.subplot(4,4,i)
    sns.boxplot(df[column])
plt.tight_layout()

# %% [markdown]
# ### this shows that after preprocessing the non hot encoded columns have been preprocessed and the outliers have been removed and the zscore's range falls between 3 and -3

# %% [markdown]
# ### now the preprocessing part of the dataset is now finished and now we can proceed in implementing linear regression in this dataset

# %% [markdown]
# ### splittting the dataset into training and testing parts

# %%
#X AND Y ARE feature values and target values respectively

X = df.drop('price' , axis = 1)
Y = df['price']

#70% trainging case and 20% testing case
i = int(0.7*len(df))
X_train = X[:i]

X_test = X[i:]

Y_train  = Y[:i]
Y_test  = Y[i:]
print(X.shape,
Y.shape,
X_train.shape,
X_test.shape,
Y_train.shape,
Y_test.shape,)
# Out:
# (181, 35) (181,) (126, 35) (55, 35) (126,) (55,)

# %%
class Linear_Regression:

    def __init__ (self , lr = 0.01 , n_iterations  = 1000 , regularization_constant  = 1):
        self.lr = lr
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None
        self.regularization_constant = regularization_constant

    def fit(self, X,y):
        number_of_samples , number_of_features  = X.shape
        #starting off the gradient descent at w1,w2,...,w34 and bias at 0
        self.weights = np.zeros(number_of_features)
        self.bias = 0 
        #gradient descent for 1000 iterations
        
        for _ in range(self.n_iterations):

            y_predict  = np.dot(X , self.weights) + self.bias # we took X and self weights in that specific order since it is a matrix multiplication

            dw  = (1/number_of_samples)*(  np.dot(X.T , y_predict  - y)) + (self.regularization_constant/number_of_samples)*(self.weights)
            # here we had to take a transpose because the shape of X is 183,34 and y predict is 183, and for matrix multiplication
            # we need 34,183 * 183, so we took transpose of matrix X
            #self.regularization constant is the value of lambda

            db  = (1/number_of_samples)*np.sum(y_predict  - y )
            #updating the weights
            
            self.weights =self.weights - self.lr*dw
            self.bias= self.bias - self.lr*db

    def predict(self,X):
        predictions  = np.dot(X,self.weights) +self.bias
        return predictions

# %%
class Error_checkers:

    def MSE(self , Y , Y_predicted):

        return np.mean((Y -Y_predicted)**2)
        # returns the MSE of the model

    def RMSE(self , Y , Y_predicted):
        return  (np.mean((Y -Y_predicted)**2))**0.5


    def Rsquared(self , Y , Y_predicted):
        return 1 - np.sum( (Y - Y_predicted)**2 ) /np.sum((Y_predicted - np.mean(Y))**2)

# %%
linearreg = Linear_Regression()
linearreg.fit(X_train , Y_train)

y_predicted  = linearreg.predict(X_test)

print(y_predicted)
checker = Error_checkers()
print("Mean Squared Error:")
print(checker.MSE(Y_test , y_predicted))

print("RMS ERROR")
print(checker.RMSE(Y_test , y_predicted))

print("R^2 ERROR")
print(checker.Rsquared(Y_test, y_predicted))
# Out:
# [-0.6791709570749852 -0.34173162078853425 -0.452701746280451
#  -0.13037430290288013 -0.1868823897303741 -0.06681828693710098
#  -0.45364477790458957 -0.2221224894870207 -0.2845691690870512
#  -0.16118884605778366 -1.0438918122318344 -1.0334733966074665
#  -1.0994339502469368 -0.9597127071657681 -0.818538597145833
#  -0.6714018359959044 -0.7249803525146166 -0.9131111304973413
#  -0.7113270995155198 -0.9143848469150119 -0.7183296253510038
#  -0.33780490778399797 -0.5243500703956325 0.43685550373472515
#  0.43613776343643273 0.18537473118224193 0.46179697910038375
#  0.21462264833765446 0.4176163112327308 -0.570949372223015
#  -0.7516862512553718 -0.5572130117882864 -0.7437911079741562
#  1.194198818147188 1.2019017043256779 1.2285407296681317
#  1.0297619742475208 -0.40487782836063224 -0.4658141999120562
#  -0.454509790213952 -0.2302451080496509 -0.47776791416150033
#  -0.6581810097285774 0.45024965529432315 -0.29350770615983945
#  0.8508212280387106 0.7628265442912526 0.854422751558325
#  0.7637365416922708 0.8908434617691005 0.8010544272759117
#  1.0154204338371626 1.2289774700202611 1.4101449047394052
#  0.9682656115378804]
# Mean Squared Error:
# 0.1879562359335508
# RMS ERROR
# 0.4335391976898407
# R^2 ERROR
# 0.6741967509432102
