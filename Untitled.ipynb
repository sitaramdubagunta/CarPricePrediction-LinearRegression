# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # REMOVING UNNECCARY FEATURES AND ONE-HOT-ENCODING

# %%
df = pd.read_csv('CarPrice_Assignment.csv')

# %%
df = df.drop(['car_ID', 'CarName' , 'symboling' ] , axis = 1)
#dropping peakrpm , fuelsystem due to redundancy and engine location because majority of them are located in the front 
df  = pd.get_dummies(df , columns=['fueltype', 'aspiration', 'doornumber', 'carbody', 
                                 'drivewheel', 'enginetype', 
                                 'cylindernumber' , 'enginelocation' , 'fuelsystem' ], drop_first=True)


df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  ...  \
# 0         3.47    2.68               9.0         111  ...
# 1         3.47    2.68               9.0         111  ...
# 2         2.68    3.47               9.0         154  ...
# 3         3.19    3.40              10.0         102  ...
# 4         3.19    3.40               8.0         115  ...
# ..         ...     ...               ...         ...  ...
# 200       3.78    3.15               9.5         114  ...
# 201       3.78    3.15               8.7         160  ...
# 202       3.58    2.87               8.8         134  ...
# 203       3.01    3.40              23.0         106  ...
# 204       3.78    3.15               9.5         114  ...
#
#      cylindernumber_twelve  cylindernumber_two  enginelocation_rear  \
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ..                     ...                 ...                  ...
# 200                  False               False                False
# 201                  False               False                False
# 202                  False               False                False
# 203                  False               False                False
# 204                  False               False                False
#
#      fuelsystem_2bbl  fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  \
# 0              False            False           False           False
# 1              False            False           False           False
# 2              False            False           False           False
# 3              False            False           False           False
# 4              False            False           False           False
# ..               ...              ...             ...             ...
# 200            False            False           False           False
# 201            False            False           False           False
# 202            False            False           False           False
# 203            False            False            True           False
# 204            False            False           False           False
#
#      fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi
# 0               True            False            False
# 1               True            False            False
# 2               True            False            False
# 3               True            False            False
# 4               True            False            False
# ..               ...              ...              ...
# 200             True            False            False
# 201             True            False            False
# 202             True            False            False
# 203            False            False            False
# 204             True            False            False
#
# [205 rows x 43 columns]

# %%
sns.histplot(df['carheight'] , kde = True)
print("carheight mean" , df['carheight'].mean())
sns.histplot(df['carwidth'] , kde = True)
# Out:
# carheight mean 53.72487804878049
# <Axes: xlabel='carheight', ylabel='Count'>

# %% [markdown]
# ## this is a non normal distribution about the mean , roughly all the coloumns potray the same

# %%
non_hot_encoded = df.select_dtypes(include=['float64', 'int64']).columns
# the hot encoded values are of uint8 that's why it gets excluded here
non_hot_encoded = non_hot_encoded.drop('price')
for i in non_hot_encoded:
    df[i] = (df[i] - df[i].mean())/df[i].std()

df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0    -1.686643  -0.425480 -0.842719  -2.015483   -0.014531    0.074267
# 1    -1.686643  -0.425480 -0.842719  -2.015483   -0.014531    0.074267
# 2    -0.706865  -0.230948 -0.190101  -0.542200    0.513625    0.602571
# 3     0.173274   0.206750  0.136209   0.235366   -0.419770   -0.430023
# 4     0.106848   0.206750  0.229440   0.235366    0.515545    0.218350
# ..         ...        ...       ...        ...         ...         ...
# 200   1.717669   1.195622  1.394830   0.726460    0.761377    0.338419
# 201   1.717669   1.195622  1.348215   0.726460    0.947672    0.338419
# 202   1.717669   1.195622  1.394830   0.726460    0.876611    1.106861
# 203   1.717669   1.195622  1.394830   0.726460    1.270327    0.434474
# 204   1.717669   1.195622  1.394830   0.726460    0.972640    0.338419
#
#      boreratio    stroke  compressionratio  horsepower  ...  \
# 0     0.517804 -1.834886         -0.287645    0.174057  ...
# 1     0.517804 -1.834886         -0.287645    0.174057  ...
# 2    -2.399008  0.684271         -0.287645    1.261448  ...
# 3    -0.516003  0.461055         -0.035885   -0.053537  ...
# 4    -0.516003  0.461055         -0.539405    0.275209  ...
# ..         ...       ...               ...         ...  ...
# 200   1.662375 -0.336147         -0.161765    0.249921  ...
# 201   1.662375 -0.336147         -0.363173    1.413178  ...
# 202   0.923942 -1.229012         -0.337997    0.755685  ...
# 203  -1.180593  0.461055          3.236992    0.047616  ...
# 204   1.662375 -0.336147         -0.161765    0.249921  ...
#
#      cylindernumber_twelve  cylindernumber_two  enginelocation_rear  \
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ..                     ...                 ...                  ...
# 200                  False               False                False
# 201                  False               False                False
# 202                  False               False                False
# 203                  False               False                False
# 204                  False               False                False
#
#      fuelsystem_2bbl  fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  \
# 0              False            False           False           False
# 1              False            False           False           False
# 2              False            False           False           False
# 3              False            False           False           False
# 4              False            False           False           False
# ..               ...              ...             ...             ...
# 200            False            False           False           False
# 201            False            False           False           False
# 202            False            False           False           False
# 203            False            False            True           False
# 204            False            False           False           False
#
#      fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi
# 0               True            False            False
# 1               True            False            False
# 2               True            False            False
# 3               True            False            False
# 4               True            False            False
# ..               ...              ...              ...
# 200             True            False            False
# 201             True            False            False
# 202             True            False            False
# 203            False            False            False
# 204             True            False            False
#
# [205 rows x 43 columns]

# %% [markdown]
# # Removing outliers using Z-Score
# ## anything falling outside the range -3 and 3  be considered as an outlier

# %%
for i in non_hot_encoded:

    outliers  = df.loc[(df[i] > 3 ) | (df[i] < -3)]

    if not outliers.empty:
        print(f'outliers in the feature \n {i}')
        print()
        print(outliers.loc[: , i])
    else:
        print(f'outliers are not present : {i}')
# Out:
# outliers in the feature
#  wheelbase
#
# 73    3.677223
# Name: wheelbase, dtype: float64
# outliers are not present : carlength
# outliers are not present : carwidth
# outliers are not present : carheight
# outliers are not present : curbweight
# outliers in the feature
#  enginesize
#
# 47    3.148036
# 48    3.148036
# 49    4.780975
# 73    4.348726
# 74    4.252671
# Name: enginesize, dtype: float64
# outliers are not present : boreratio
# outliers in the feature
#  stroke
#
# 111   -3.397400
# 113   -3.397400
# 134   -3.780057
# Name: stroke, dtype: float64
# outliers in the feature
#  compressionratio
#
# 63     3.161464
# 158    3.111112
# 159    3.111112
# 174    3.111112
# 182    3.236992
# 184    3.236992
# 187    3.236992
# 192    3.236992
# 203    3.236992
# Name: compressionratio, dtype: float64
# outliers in the feature
#  horsepower
#
# 49     3.992572
# 129    4.650065
# Name: horsepower, dtype: float64
# outliers in the feature
#  peakrpm
#
# 165    3.092081
# 166    3.092081
# Name: peakrpm, dtype: float64
# outliers in the feature
#  citympg
#
# 18    3.329260
# 30    3.634970
# 90    3.023549
# Name: citympg, dtype: float64
# outliers in the feature
#  highwaympg
#
# 18    3.230809
# 30    3.376022
# Name: highwaympg, dtype: float64

# %% [markdown]
# ## deleting these outliers from the set

# %%
for i in non_hot_encoded:
    df = df.query(f"({i} <= 3) & ({i} >= -3)")
df.reset_index(drop=True, inplace=True)

# %%
for i , column in enumerate(non_hot_encoded , 1):
    plt.subplot(4,4,i)
    sns.boxplot(df[column])
plt.tight_layout()

# %% [markdown]
# # checking for data redundancy

# %%
dfcorr = df.select_dtypes(include=['float64', 'int64']).corr()
dfcorr = dfcorr.drop(['price'] )
dfcorr = dfcorr.drop(['price'] , axis  = 1 )

dfcorr
# Out:
#                   wheelbase  carlength  carwidth  carheight  curbweight  \
# wheelbase          1.000000   0.852368  0.786984   0.641451    0.739084
# carlength          0.852368   1.000000  0.835202   0.530854    0.864825
# carwidth           0.786984   0.835202  1.000000   0.329619    0.845903
# carheight          0.641451   0.530854  0.329619   1.000000    0.363776
# curbweight         0.739084   0.864825  0.845903   0.363776    1.000000
# enginesize         0.506814   0.676225  0.697493   0.154245    0.847753
# boreratio          0.481204   0.633290  0.540278   0.234309    0.655416
# stroke             0.212342   0.188920  0.253883  -0.026778    0.207274
# compressionratio   0.451432   0.296600  0.336216   0.301641    0.352694
# horsepower         0.302416   0.549088  0.580943  -0.037641    0.736997
# peakrpm           -0.362596  -0.294193 -0.209815  -0.318732   -0.282606
# citympg           -0.401549  -0.654429 -0.631395  -0.080657   -0.762429
# highwaympg        -0.485576  -0.691982 -0.683243  -0.152222   -0.813440
#
#                   enginesize  boreratio    stroke  compressionratio  \
# wheelbase           0.506814   0.481204  0.212342          0.451432
# carlength           0.676225   0.633290  0.188920          0.296600
# carwidth            0.697493   0.540278  0.253883          0.336216
# carheight           0.154245   0.234309 -0.026778          0.301641
# curbweight          0.847753   0.655416  0.207274          0.352694
# enginesize          1.000000   0.593002  0.219347          0.220866
# boreratio           0.593002   1.000000 -0.139118          0.219136
# stroke              0.219347  -0.139118  1.000000          0.207970
# compressionratio    0.220866   0.219136  0.207970          1.000000
# horsepower          0.806652   0.542945  0.116382         -0.075518
# peakrpm            -0.258275  -0.322948 -0.008061         -0.442339
# citympg            -0.672102  -0.560274 -0.124034          0.118698
# highwaympg         -0.690829  -0.572966 -0.112867          0.035211
#
#                   horsepower   peakrpm   citympg  highwaympg
# wheelbase           0.302416 -0.362596 -0.401549   -0.485576
# carlength           0.549088 -0.294193 -0.654429   -0.691982
# carwidth            0.580943 -0.209815 -0.631395   -0.683243
# carheight          -0.037641 -0.318732 -0.080657   -0.152222
# curbweight          0.736997 -0.282606 -0.762429   -0.813440
# enginesize          0.806652 -0.258275 -0.672102   -0.690829
# boreratio           0.542945 -0.322948 -0.560274   -0.572966
# stroke              0.116382 -0.008061 -0.124034   -0.112867
# compressionratio   -0.075518 -0.442339  0.118698    0.035211
# horsepower          1.000000  0.116377 -0.832377   -0.802764
# peakrpm             0.116377  1.000000 -0.077541   -0.007846
# citympg            -0.832377 -0.077541  1.000000    0.967382
# highwaympg         -0.802764 -0.007846  0.967382    1.000000

# %% [markdown]
# ### Here lets check curbweight vs carlength and curbweight vs carheight which output 0.86 and 0.84 which are considered very high and require investigation
#
# #### after investigating curbweigth dropping the feature actually made the performance worse , it doesn't require to be dropped

# %%
sns.heatmap(dfcorr)
# Out:
# <Axes: >

# %% [markdown]
# ### now the preprocessing part of the dataset is now finished and now we can proceed in implementing linear regression in this dataset

# %% [markdown]
# ### splittting the dataset into training and testing parts

# %%
#X AND Y ARE feature values and target values respectively

X = df.drop('price' , axis = 1)
Y = df['price']

#70% trainging case and 30% testing case
i = int(0.7*len(df))
X_train = X[:i]

X_test = X[i:]

Y_train  = Y[:i]
Y_test  = Y[i:]
print(X.shape,
Y.shape,
X_train.shape,
X_test.shape,
Y_train.shape,
Y_test.shape,)
# Out:
# (182, 42) (182,) (127, 42) (55, 42) (127,) (55,)

# %%
class Linear_Regression:

    def __init__ (self , lr = 0.01 , n_iterations  = 1000 , regularization_constant  = 1):
        self.lr = lr
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None
        self.regularization_constant = regularization_constant

    def fit(self, X,y):
        number_of_samples , number_of_features  = X.shape
        #starting off the gradient descent at w1,w2,...,w34 and bias at 0
        self.weights = np.zeros(number_of_features)
        self.bias = 0 
        #gradient descent for 1000 iterations
        
        for _ in range(self.n_iterations):

            y_predict  = np.dot(X , self.weights) + self.bias # we took X and self weights in that specific order since it is a matrix multiplication

            dw  = (1/number_of_samples)*(  np.dot(X.T , y_predict  - y)) + (self.regularization_constant/number_of_samples)*(self.weights)
            # here we had to take a transpose because the shape of X is 183,34 and y predict is 183, and for matrix multiplication
            # we need 34,183 * 183, so we took transpose of matrix X
            #self.regularization constant is the value of lambda

            db  = (1/number_of_samples)*np.sum(y_predict  - y )
            #updating the weights
            
            self.weights =self.weights - self.lr*dw
            self.bias= self.bias - self.lr*db

    def predict(self,X):
        predictions  = np.dot(X,self.weights) +self.bias
        return predictions

# %%
class Statistical_Methods:
  ## checks for errors
    def MSE(self , Y , Y_predicted):

        return np.mean((Y -Y_predicted)**2)
        # returns the MSE of the model

    def RMSE(self , Y , Y_predicted):
        return  (np.mean((Y -Y_predicted)**2))**0.5

# performance metric
    def Rsquared(self , Y , Y_predicted):
        return 1 - np.sum( (Y - Y_predicted)**2 ) /np.sum((Y_predicted - np.mean(Y))**2)

# %%
linearreg = Linear_Regression()
linearreg.fit(X_train , Y_train)

y_predicted  = linearreg.predict(X_test)

print(y_predicted)
checker = Statistical_Methods()
print("Mean Squared Error:")
print(checker.MSE(Y_test , y_predicted))

print("RMS ERROR")
print(checker.RMSE(Y_test , y_predicted))

print("R^2 ERROR")
print(checker.Rsquared(Y_test, y_predicted))
# Out:
# [4938.048872033719 8546.306182600089 7655.473071914972 10885.475858623973
#  9084.214704073653 9768.297327671633 7599.319650511419 9943.680245010995
#  7755.23832315385 9074.397832389808 4704.422555897749 4978.697484709577
#  3299.089749627812 4929.179652490872 4802.048781872866 7012.663465493232
#  6833.360217004389 4844.679803978081 6334.794264906224 5030.72972350382
#  7142.459642805019 11598.919582986888 9630.070856651393 17027.86241249277
#  17017.078926231206 15701.93226949501 17402.588560082073 16141.35933465369
#  17262.16212573297 7665.175015664301 5950.207105677579 8018.214265467144
#  6068.82545455477 22948.842216783054 23079.37731829572 22932.6807258293
#  20871.031105481383 11063.320938892914 9459.197607642087 9629.037516261702
#  11985.097169675815 9613.54313332053 9051.508599632423 16730.40168259729
#  11149.265807216952 21193.07149409308 20205.967595229195 21232.37630120003
#  20204.834328855282 21537.57591874573 20523.513304227938 22364.13748228235
#  24288.393107442454 24305.328294521714 22620.72206348481]
# Mean Squared Error:
# 14486892.673733508
# RMS ERROR
# 3806.1650875564383
# R^2 ERROR
# 0.6736387979102197
